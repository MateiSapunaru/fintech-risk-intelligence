# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_data
from src.preprocessing import split_data, build_preprocessor
from src.modeling import build_xgboost_pipeline, evaluate_classification_model

# %%
df = load_data()

X_train, X_test, y_train, y_test = split_data(df)
preprocessor = build_preprocessor(X_train)

# %%
xgb_model = build_xgboost_pipeline(preprocessor)
xgb_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Age', 'Income', 'LoanAmount', 'CreditScore', 'YearsExperience'], dtype='str')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
xgb_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Age', 'Income', 'LoanAmount', 'CreditScore', 'YearsExperience'], dtype='str')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
metrics_xgb, report_xgb, cm_xgb = evaluate_classification_model(
    xgb_model, X_train, X_test, y_train, y_test
)

metrics_xgb
# Out:
# {'train_accuracy': 0.97125,
#  'test_accuracy': 0.965,
#  'train_precision': 0.965556831228473,
#  'test_precision': 0.9523809523809523,
#  'train_recall': 0.908207343412527,
#  'test_recall': 0.8888888888888888,
#  'train_f1': 0.9360044518642181,
#  'test_f1': 0.9195402298850575,
#  'train_roc_auc': 0.9974224703533152,
#  'test_roc_auc': 0.9419584229390682}

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(cm_xgb, annot=True, fmt="d", cmap="Blues")
plt.title("XGBoost - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
feature_names = xgb_model.named_steps["preprocessor"].get_feature_names_out()
importances = xgb_model.named_steps["classifier"].feature_importances_

feat_imp_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

feat_imp_df.head(10)
feat_imp_df.tail(10)
# Out:
#                      feature  importance
# 11         cat__City_Chicago    0.011530
# 5         cat__Gender_Female    0.011433
# 0                   num__Age    0.011379
# 4       num__YearsExperience    0.010994
# 13        cat__City_New York    0.010687
# 12         cat__City_Houston    0.010656
# 6           cat__Gender_Male    0.009548
# 7   cat__Education_Bachelors    0.009254
# 14   cat__City_San Francisco    0.009251
# 9     cat__Education_Masters    0.007995

# %%
top_features = feat_imp_df.head(10)

plt.figure(figsize=(10, 6))
plt.barh(top_features["feature"], top_features["importance"])
plt.gca().invert_yaxis()
plt.title("Top XGBoost Feature Importances")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %%
top_features = feat_imp_df.tail(10)

plt.figure(figsize=(10, 6))
plt.barh(top_features["feature"], top_features["importance"])
plt.gca().invert_yaxis()
plt.title("Top XGBoost Feature Least Importances")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()
